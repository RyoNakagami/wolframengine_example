# %%
$Version
# Out:
# 13.2.0 for Linux x86 (64-bit) (December 12, 2022)

# %%
WolframAlpha["x + sqrt[x^2 + 1] == exp[1]", 
            IncludePods->{"Solution"},
            PodStates->{"Solution__Step-by-step solution"}]
# Out:
# DynamicNamespace[WolframAlphaQueryResults,
#
# >   DynamicModule[{Typeset`q = x + sqrt[x^2 + 1] == exp[1],
#
# >     Typeset`opts =
#
# >      {AppearanceElements ->
#
# >        {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources},
#
# >       IncludePods -> {Solution}, PodStates -> {Solution__Step-by-step solution}},
#
# >     Typeset`elements =
#
# >      {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources},
#
# >     Typeset`pod1 =
#
# >      XMLElement[pod, {title -> Solutions, scanner -> Reduce, id -> Solution,
#
# >        position -> 100, error -> false, numsubpods -> 2, primary -> true},
#
# >       {XMLElement[subpod, {title -> },
#
# >         {XMLElement[minput, {}, {Reduce[x + Sqrt[1 + x^2] == E, x, Reals]}],
#
# >          XMLElement[cell, {compressed -> False, string -> True},
#
# >           {Cell[BoxData[FormBox[FormBox[FormBox[TagBox[GridBox[{{PaneBox[
#
# >                      RowBox[{x, ,
#
# ...
