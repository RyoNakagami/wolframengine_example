# %%
$Version
# Out:
# 13.2.0 for Linux x86 (64-bit) (December 12, 2022)

# %%
WolframAlpha["d(cos(x)*log(cos(x)) - cos(x)) / dx", 
             {{"Input", 2}, "Content"}, 
             PodStates -> {"Input__Step-by-step solution"}]
# Out:
# RawBoxes[StyleBox[FormBox[StyleBox[GridBox[{{StyleBox[GridBox[{{StyleBox[
#
# >              StyleBox[TemplateBox[{"Possible derivation:"}, RowDefault],
#
# >               GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                 RowBox[{(, RowBox[{RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                       RowBox[{log, (, RowBox[{cos, (, x, )}], )}]}], -,
#
# >                     RowBox[{cos, (, x, )}]}], )}]}], HoldForm],
#
# >              AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}},
#
# >           GridBoxSpacings -> {Columns -> {{None}}, Rows -> {{0.5}}}], Column]},
#
# >        {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"Differentiate ", "the ",
#
# >                 "sum ", "term ", "by ", "term ", "and ", "factor ", "out ",
#
# >                 "constants:"}, RowDefault], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 FormBox[RowBox[{RowBox[{-,
#
# >                      RowBox[{(, FormBox[RowBox[{FractionBox[, RowBox[{"", , x}]],
#
# >                           , RowBox[{(, RowBox[{cos, (, x, )}], )}]}], TraditionalForm]
#
# >                         , )}]}], +,
#
# >                    TagBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                       RowBox[{(, RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                           RowBox[{log, (, RowBox[{cos, (, x, )}], )}]}], )}]}],
#
# >                     HoldForm]}], TraditionalForm]}, RowDefault], HoldForm],
#
# >              AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"Using ",
#
# >                 "the ", "chain ", "rule, ",
#
# >                 TemplateBox[{RowBox[{RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                       RowBox[{(, RowBox[{cos, (, x, )}], )}]}], ,
#
# >                     FormBox[StyleBox[TagBox[TagBox[RowBox[{FractionBox[
#
# >                            RowBox[{, RowBox[{cos, (, u, )}]}], RowBox[{, u}],
#
# >                            MultilineFunction -> None],  ,
#
# >                           FractionBox[RowBox[{, u}], RowBox[{, x}],
#
# >                            MultilineFunction -> None]}], HoldForm],
#
# >                        PolynomialForm[#1, TraditionalOrder -> False] & ],
#
# >                       AutoMultiplicationSymbol -> True], TraditionalForm]}], ",", " "}\
#
# >                   , RowDefault], "where ",
#
# >                 TemplateBox[{TemplateBox[{,, ",", RowBox[{u, , x}]},
#
# >                    RowWithSeparators], " "}, RowDefault], "and ",
#
# >                 TemplateBox[{StyleBox[TagBox[TemplateBox[{,, ",",
#
# >                       RowBox[{RowBox[{FractionBox[RowBox[{, ""}], RowBox[{, u}],
#
# >                            MultilineFunction -> None], ,
#
# >                           RowBox[{(, RowBox[{cos, (, u, )}], )}]}], ,
#
# >                         RowBox[{-, RowBox[{sin, (, u, )}]}]}]}, RowWithSeparators],
#
# >                     HoldForm], AutoMultiplicationSymbol -> True], ":"}, RowDefault]},
#
# >                RowDefault], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 RowBox[{TagBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                      RowBox[{(, RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                          RowBox[{log, (, RowBox[{cos, (, x, )}], )}]}], )}]}],
#
# >                    HoldForm], -, FrameBox[RowBox[{-,
#
# >                      RowBox[{(, FormBox[RowBox[{FractionBox[, RowBox[{"", , x}]],
#
# >                           , RowBox[{(, x, )}]}], TraditionalForm], )}],  ,
#
# >                      RowBox[{sin, (, x, )}]}], FrameStyle -> GrayLevel[0.8],
#
# >                    FrameMargins -> 1, BaselinePosition -> Baseline,
#
# >                    ContentPadding -> False, StripOnInput -> False]}]}, RowDefault],
#
# >               HoldForm], AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{⁠, "⁠",
#
# >                 TemplateBox[{"Simplify ", "the ", "expression"}, RowDefault], ":"},
#
# >                RowWithSeparators], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 StyleBox[TagBox[RowBox[{TagBox[RowBox[{FractionBox[,
#
# >                         RowBox[{"", , x}]], ,
#
# >                        RowBox[{(,
#
# >                          RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                            RowBox[{log, (, RowBox[{cos, (, x, )}], )}]}], )}]}],
#
# >                      HoldForm], +,
#
# >                     RowBox[{RowBox[{(,
#
# >                         TagBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                            RowBox[{(, x, )}]}], HoldForm], )}],  ,
#
# >                       RowBox[{sin, (, x, )}]}]}], HoldForm],
#
# >                  AutoMultiplicationSymbol -> True]}, RowDefault], HoldForm],
#
# >              AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"The ",
#
# >                 "derivative ", "of ",
#
# >                 TemplateBox[{FormBox[x, TraditionalForm], " "}, RowDefault], "is ",
#
# >                 TemplateBox[{1, ":"}, RowDefault]}, RowDefault], GrayLevel[0.3],
#
# >               StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 RowBox[{FormBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                      RowBox[{(, RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                          RowBox[{log, (, RowBox[{cos, (, x, )}], )}]}], )}]}],
#
# >                    TraditionalForm], +,
#
# >                   TemplateBox[{TemplateBox[{FrameBox[1, FrameStyle -> GrayLevel[0.8],
#
# >                        FrameMargins -> 1, BaselinePosition -> Baseline,
#
# >                        ContentPadding -> False, StripOnInput -> False], " "},
#
# >                      RowDefault], RowBox[{sin, (, x, )}]}, RowDefault]}]}, RowDefault]\
#
# >                , HoldForm], AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"Use ", "the ",
#
# >                 "product ", "rule, ",
#
# >                 TemplateBox[{RowBox[{RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                       RowBox[{(, RowBox[{u,  , v}], )}]}], ,
#
# >                     FormBox[StyleBox[TagBox[TagBox[RowBox[{RowBox[{v,  ,
#
# >                             FractionBox[RowBox[{, u}], RowBox[{, x}],
#
# >                              MultilineFunction -> None]}], +,
#
# >                           RowBox[{u,  ,
#
# >                             FractionBox[RowBox[{, v}], RowBox[{, x}],
#
# >                              MultilineFunction -> None]}]}], HoldForm],
#
# >                        PolynomialForm[#1, TraditionalOrder -> False] & ],
#
# >                       AutoMultiplicationSymbol -> True], TraditionalForm]}], ",", " "}\
#
# >                   , RowDefault], "where ",
#
# >                 TemplateBox[{RowBox[{u, , RowBox[{cos, (, x, )}]}], " "},
#
# >                  RowDefault], "and ",
#
# >                 TemplateBox[{RowBox[{v, ,
#
# >                     RowBox[{log, (, RowBox[{cos, (, x, )}], )}]}], ":"}, RowDefault]},
#
# >                RowDefault], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 RowBox[{RowBox[{sin, (, x, )}], +,
#
# >                   FrameBox[RowBox[{(,
#
# >                      RowBox[{RowBox[{RowBox[{log, (, RowBox[{cos, (, x, )}], )}],  ,
#
# >                          RowBox[{(,
#
# >                            FormBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                               RowBox[{(, RowBox[{cos, (, x, )}], )}]}],
#
# >                             TraditionalForm], )}]}], +,
#
# >                        RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                          RowBox[{(,
#
# >                            TagBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                               RowBox[{(, RowBox[{log, (, RowBox[{cos, (, x, )}], )}],
#
# >                               )}]}], HoldForm], )}]}]}], )}],
#
# >                    FrameStyle -> GrayLevel[0.8], FrameMargins -> 1,
#
# >                    BaselinePosition -> Baseline, ContentPadding -> False,
#
# >                    StripOnInput -> False]}]}, RowDefault], HoldForm],
#
# >              AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{⁠, "⁠",
#
# >                 TemplateBox[{"Simplify ", "the ", "expression"}, RowDefault], ":"},
#
# >                RowWithSeparators], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 StyleBox[TagBox[RowBox[{RowBox[{RowBox[{log, (,
#
# >                         RowBox[{cos, (, x, )}], )}],  ,
#
# >                       RowBox[{(, TagBox[RowBox[{FractionBox[, RowBox[{"", , x}]],
#
# >                            , RowBox[{(, RowBox[{cos, (, x, )}], )}]}], HoldForm], )}]}
#
# >                       ], +, RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                       RowBox[{(, TagBox[RowBox[{FractionBox[, RowBox[{"", , x}]],
#
# >                            , RowBox[{(, RowBox[{log, (, RowBox[{cos, (, x, )}], )}],
#
# >                              )}]}], HoldForm], )}]}], +, RowBox[{sin, (, x, )}]}],
#
# >                   HoldForm], AutoMultiplicationSymbol -> True]}, RowDefault], HoldForm]
#
# >               , AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"Using ",
#
# >                 "the ", "chain ", "rule, ",
#
# >                 TemplateBox[{RowBox[{RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                       RowBox[{(, RowBox[{cos, (, x, )}], )}]}], ,
#
# >                     FormBox[StyleBox[TagBox[TagBox[RowBox[{FractionBox[
#
# >                            RowBox[{, RowBox[{cos, (, u, )}]}], RowBox[{, u}],
#
# >                            MultilineFunction -> None],  ,
#
# >                           FractionBox[RowBox[{, u}], RowBox[{, x}],
#
# >                            MultilineFunction -> None]}], HoldForm],
#
# >                        PolynomialForm[#1, TraditionalOrder -> False] & ],
#
# >                       AutoMultiplicationSymbol -> True], TraditionalForm]}], ",", " "}\
#
# >                   , RowDefault], "where ",
#
# >                 TemplateBox[{TemplateBox[{,, ",", RowBox[{u, , x}]},
#
# >                    RowWithSeparators], " "}, RowDefault], "and ",
#
# >                 TemplateBox[{StyleBox[TagBox[TemplateBox[{,, ",",
#
# >                       RowBox[{RowBox[{FractionBox[RowBox[{, ""}], RowBox[{, u}],
#
# >                            MultilineFunction -> None], ,
#
# >                           RowBox[{(, RowBox[{cos, (, u, )}], )}]}], ,
#
# >                         RowBox[{-, RowBox[{sin, (, u, )}]}]}]}, RowWithSeparators],
#
# >                     HoldForm], AutoMultiplicationSymbol -> True], ":"}, RowDefault]},
#
# >                RowDefault], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 RowBox[{RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                     RowBox[{(, TagBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                          RowBox[{(, RowBox[{log, (, RowBox[{cos, (, x, )}], )}], )}]}]\
#
# >                         , HoldForm], )}]}], +, RowBox[{sin, (, x, )}], +,
#
# >                   TemplateBox[{TemplateBox[{FrameBox[RowBox[{-,
#
# >                          RowBox[{(,
#
# >                            FormBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                               RowBox[{(, x, )}]}], TraditionalForm], )}],  ,
#
# >                          RowBox[{sin, (, x, )}]}], FrameStyle -> GrayLevel[0.8],
#
# >                        FrameMargins -> 1, BaselinePosition -> Baseline,
#
# >                        ContentPadding -> False, StripOnInput -> False], " "},
#
# >                      RowDefault], RowBox[{log, (, RowBox[{cos, (, x, )}], )}]},
#
# >                    RowDefault]}]}, RowDefault], HoldForm],
#
# >              AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"The ",
#
# >                 "derivative ", "of ",
#
# >                 TemplateBox[{FormBox[x, TraditionalForm], " "}, RowDefault], "is ",
#
# >                 TemplateBox[{1, ":"}, RowDefault]}, RowDefault], GrayLevel[0.3],
#
# >               StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 RowBox[{RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                     RowBox[{(, FormBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                          RowBox[{(, RowBox[{log, (, RowBox[{cos, (, x, )}], )}], )}]}]\
#
# >                         , TraditionalForm], )}]}], +, RowBox[{sin, (, x, )}], -,
#
# >                   TemplateBox[{TemplateBox[{FrameBox[1, FrameStyle -> GrayLevel[0.8],
#
# >                        FrameMargins -> 1, BaselinePosition -> Baseline,
#
# >                        ContentPadding -> False, StripOnInput -> False], " "},
#
# >                      RowDefault],
#
# >                     RowBox[{RowBox[{log, (, RowBox[{cos, (, x, )}], )}],  ,
#
# >                       RowBox[{sin, (, x, )}]}]}, RowDefault]}]}, RowDefault], HoldForm]
#
# >               , AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"Using ",
#
# >                 "the ", "chain ", "rule, ",
#
# >                 TemplateBox[{RowBox[{RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                       RowBox[{(, RowBox[{log, (, RowBox[{cos, (, x, )}], )}], )}]}],
#
# >                     , FormBox[StyleBox[TagBox[TagBox[RowBox[{FractionBox[
#
# >                            RowBox[{, RowBox[{log, (, u, )}]}], RowBox[{, u}],
#
# >                            MultilineFunction -> None],  ,
#
# >                           FractionBox[RowBox[{, u}], RowBox[{, x}],
#
# >                            MultilineFunction -> None]}], HoldForm],
#
# >                        PolynomialForm[#1, TraditionalOrder -> False] & ],
#
# >                       AutoMultiplicationSymbol -> True], TraditionalForm]}], ",", " "}\
#
# >                   , RowDefault], "where ",
#
# >                 TemplateBox[{TemplateBox[{,, ",",
#
# >                     RowBox[{u, , RowBox[{cos, (, x, )}]}]}, RowWithSeparators], " "},
#
# >                  RowDefault], "and ",
#
# >                 TemplateBox[{StyleBox[TagBox[TemplateBox[{,, ",",
#
# >                       RowBox[{RowBox[{FractionBox[RowBox[{, ""}], RowBox[{, u}],
#
# >                            MultilineFunction -> None], ,
#
# >                           RowBox[{(, RowBox[{log, (, u, )}], )}]}], ,
#
# >                         FractionBox[1, u]}]}, RowWithSeparators], HoldForm],
#
# >                    AutoMultiplicationSymbol -> True], ":"}, RowDefault]}, RowDefault],
#
# >               GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 RowBox[{RowBox[{sin, (, x, )}], -,
#
# >                   RowBox[{RowBox[{log, (, RowBox[{cos, (, x, )}], )}],  ,
#
# >                     RowBox[{sin, (, x, )}]}], +,
#
# >                   TemplateBox[{TemplateBox[{FrameBox[RowBox[{RowBox[{(,
#
# >                            FormBox[RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                               RowBox[{(, RowBox[{cos, (, x, )}], )}]}],
#
# >                             TraditionalForm], )}],  , RowBox[{sec, (, x, )}]}],
#
# >                        FrameStyle -> GrayLevel[0.8], FrameMargins -> 1,
#
# >                        BaselinePosition -> Baseline, ContentPadding -> False,
#
# >                        StripOnInput -> False], " "}, RowDefault],
#
# >                     RowBox[{cos, (, x, )}]}, RowDefault]}]}, RowDefault], HoldForm],
#
# >              AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{⁠, "⁠",
#
# >                 TemplateBox[{"Simplify ", "the ", "expression"}, RowDefault], ":"},
#
# >                RowWithSeparators], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 StyleBox[TagBox[RowBox[{TagBox[RowBox[{FractionBox[,
#
# >                         RowBox[{"", , x}]], ,
#
# >                        RowBox[{(, RowBox[{cos, (, x, )}], )}]}], HoldForm], +,
#
# >                     RowBox[{sin, (, x, )}], -,
#
# >                     RowBox[{RowBox[{log, (, RowBox[{cos, (, x, )}], )}],  ,
#
# >                       RowBox[{sin, (, x, )}]}]}], HoldForm],
#
# >                  AutoMultiplicationSymbol -> True]}, RowDefault], HoldForm],
#
# >              AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"Using ",
#
# >                 "the ", "chain ", "rule, ",
#
# >                 TemplateBox[{RowBox[{RowBox[{FractionBox[, RowBox[{"", , x}]], ,
#
# >                       RowBox[{(, RowBox[{cos, (, x, )}], )}]}], ,
#
# >                     FormBox[StyleBox[TagBox[TagBox[RowBox[{FractionBox[
#
# >                            RowBox[{, RowBox[{cos, (, u, )}]}], RowBox[{, u}],
#
# >                            MultilineFunction -> None],  ,
#
# >                           FractionBox[RowBox[{, u}], RowBox[{, x}],
#
# >                            MultilineFunction -> None]}], HoldForm],
#
# >                        PolynomialForm[#1, TraditionalOrder -> False] & ],
#
# >                       AutoMultiplicationSymbol -> True], TraditionalForm]}], ",", " "}\
#
# >                   , RowDefault], "where ",
#
# >                 TemplateBox[{TemplateBox[{,, ",", RowBox[{u, , x}]},
#
# >                    RowWithSeparators], " "}, RowDefault], "and ",
#
# >                 TemplateBox[{StyleBox[TagBox[TemplateBox[{,, ",",
#
# >                       RowBox[{RowBox[{FractionBox[RowBox[{, ""}], RowBox[{, u}],
#
# >                            MultilineFunction -> None], ,
#
# >                           RowBox[{(, RowBox[{cos, (, u, )}], )}]}], ,
#
# >                         RowBox[{-, RowBox[{sin, (, u, )}]}]}]}, RowWithSeparators],
#
# >                     HoldForm], AutoMultiplicationSymbol -> True], ":"}, RowDefault]},
#
# >                RowDefault], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 RowBox[{RowBox[{sin, (, x, )}], -,
#
# >                   RowBox[{RowBox[{log, (, RowBox[{cos, (, x, )}], )}],  ,
#
# >                     RowBox[{sin, (, x, )}]}], +,
#
# >                   FrameBox[RowBox[{-,
#
# >                      RowBox[{(, FormBox[RowBox[{FractionBox[, RowBox[{"", , x}]],
#
# >                           , RowBox[{(, x, )}]}], TraditionalForm], )}],  ,
#
# >                      RowBox[{sin, (, x, )}]}], FrameStyle -> GrayLevel[0.8],
#
# >                    FrameMargins -> 1, BaselinePosition -> Baseline,
#
# >                    ContentPadding -> False, StripOnInput -> False]}]}, RowDefault],
#
# >               HoldForm], AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"The ",
#
# >                 "derivative ", "of ",
#
# >                 TemplateBox[{FormBox[x, TraditionalForm], " "}, RowDefault], "is ",
#
# >                 TemplateBox[{1, ":"}, RowDefault]}, RowDefault], GrayLevel[0.3],
#
# >               StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                 RowBox[{RowBox[{sin, (, x, )}], -,
#
# >                   RowBox[{RowBox[{log, (, RowBox[{cos, (, x, )}], )}],  ,
#
# >                     RowBox[{sin, (, x, )}]}], -,
#
# >                   TemplateBox[{TemplateBox[{FrameBox[1, FrameStyle -> GrayLevel[0.8],
#
# >                        FrameMargins -> 1, BaselinePosition -> Baseline,
#
# >                        ContentPadding -> False, StripOnInput -> False], " "},
#
# >                      RowDefault], RowBox[{sin, (, x, )}]}, RowDefault]}]}, RowDefault]\
#
# >                , HoldForm], AutoMultiplicationSymbol -> True]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{⁠, "⁠",
#
# >                 TemplateBox[{"Simplify ", "the ", "expression"}, RowDefault], ":"},
#
# >                RowWithSeparators], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {FrameBox[StyleBox[GridBox[{{StyleBox[TemplateBox[{"Answer:"}, RowDefault],
#
# >                   FontFamily -> Roboto, FontSize -> 12, StripOnInput -> False], },
#
# >                 {"", StyleBox[TagBox[TemplateBox[{" ", " ",
#
# >                      StyleBox[TagBox[RowBox[{-,
#
# >                          RowBox[{log, (, RowBox[{cos, (, x, )}], )}],  ,
#
# >                          RowBox[{sin, (, x, )}]}], HoldForm],
#
# >                       AutoMultiplicationSymbol -> True]}, RowDefault], HoldForm],
#
# >                   AutoMultiplicationSymbol -> True]}},
#
# >                GridBoxAlignment -> {Columns -> {{Left}}, Rows -> {{Baseline}}},
#
# >                AutoDelete -> False, GridBoxItemSize -> {Columns -> {2.5, Automatic}},
#
# >                GridBoxSpacings -> {Columns -> {2, 0, 3}, Rows -> {1.5, 1, 2}},
#
# >                AllowScriptLevelChange -> False], Grid],
#
# >              FrameStyle ->
#
# >               Directive[AbsoluteThickness[1], RGBColor[0.52, 0.76, 0.86]],
#
# >              Background -> RGBColor[0.91, 0.98, 1], RoundingRadius -> 3,
#
# >              FrameMargins -> 12, StripOnInput -> False]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}}, GridBoxAlignment -> {Columns -> {{Left}}},
#
# >       AllowScriptLevelChange -> False, DefaultBaseStyle -> Column,
#
# >       GridBoxDividers -> {Columns -> {{False}}, Rows -> {False, {True}, False}},
#
# >       GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}},
#
# >       GridBoxSpacings -> {Columns -> {{Automatic}}, Rows -> {{3}}},
#
# >       FrameStyle -> GrayLevel[0.7]], Column], TraditionalForm], Output,
#
# >    Background -> None, GraphicsBoxOptions ->
#
# >     {DefaultBaseStyle -> {FontFamily -> Times, Graphics},
#
# >      DefaultAxesStyle ->
#
# >       Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25], FontOpacity -> 1,
#
# >        GraphicsAxes], DefaultFrameStyle ->
#
# >       Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25], FontOpacity -> 1,
#
# >        GraphicsFrame], DefaultFrameTicksStyle ->
#
# >       Directive[FontFamily -> Times, FontSize -> 10, GraphicsFrameTicks],
#
# >      DefaultTicksStyle ->
#
# >       Directive[FontFamily -> Times, FontSize -> 10, GraphicsTicks]},
#
# >    Graphics3DBoxOptions -> {DefaultBaseStyle -> {FontFamily -> Times, Graphics3D}},
#
# >    NumberPoint -> ., CellSize -> {550, Automatic},
#
# >    AutoStyleOptions -> {HighlightFormattingErrors -> False},
#
# >    RenderingOptions -> {3DRenderingMethod -> BSPTreeOrDepthBuffer},
#
# >    FontFamily -> Times, FontSize -> 14, ScriptLevel -> 0, Background -> None]]

# %%
WolframAlpha["Plot[-sqrt[2] * sin[x - pi/4] * log[cos[x]], {x, 0, Pi/2}]"]
# Out:
# DynamicNamespace[WolframAlphaQueryResults,
#
# >   DynamicModule[{Typeset`q =
#
# >      Plot[-sqrt[2] * sin[x - pi/4] * log[cos[x]], {x, 0, Pi/2}],
#
# >     Typeset`opts =
#
# >      {AppearanceElements ->
#
# >        {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources}},
#
# >     Typeset`elements =
#
# >      {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources},
#
# >     Typeset`pod1 =
#
# >      XMLElement[pod, {title -> Input interpretation, scanner -> Identity, id -> Input,
#
# >        position -> 100, error -> false, numsubpods -> 1},
#
# >       {XMLElement[subpod, {title -> },
#
# >         {XMLElement[minput, {}, {Plot[-(Sqrt[2] (Sin[x - Pi/4] Log[Cos[x]])), {x, 0,\
#
# >             Pi/2}]}], XMLElement[cell, {compressed -> False, string -> True},
#
# >           {Cell[BoxData[FormBox[TagBox[TagBox[GridBox[{{PaneBox[StyleBox[
#
# >                      TagBox[GridBox[{{StyleBox["plot",
#
# >                           {LineIndent -> 0, LineSpacing -> {0.9, 0, 1.5}}],
#
# >                          TagBox[RowBox[{RowBox[{-, SqrtBox[2]}],  ,
#
# >                             RowBox[{(,
#
# >                               TagBox[RowBox[{RowBox[{sin, (,
#
# >                               RowBox[{x, -,
#
# >                               TagBox[FractionBox[π, 4],
#
# >                               PolynomialForm[#1, TraditionalOrder -> False] & ]}], )}]\
#
# >                               ,  , RowBox[{log, (, RowBox[{cos, (, x, )}], )}]}],
#
# >                               PolynomialForm[#1, TraditionalOrder -> False] & ], )}]}]\
#
# >                            , HoldForm],
#
# >                          TemplateBox[{StyleBox[RowBox[{x, ,
#
# >                               StyleBox[TagBox[0, HoldForm], GrayLevel[0],
#
# >                               StripOnInput -> False]}],
#
# >                             {GrayLevel[0.6],
#
# >                              LinebreakAdjustments -> {1, 100, 1, 0, 100},
#
# >                              LineIndent -> 0}],
#
# >                            StyleBox[" to ",
#
# >                             {GrayLevel[0.6],
#
# >                              LinebreakAdjustments -> {1, 100, 1, 0, 100},
#
# >                              LineIndent -> 0}], TagBox[FractionBox[π, 2], HoldForm]},
#
# >                           RowDefault]}},
#
# >                        GridBoxBackground ->
#
# >                         {Columns -> {GrayLevel[0.949], None, None}, Rows -> {{None}}},
#
# >                        GridBoxItemSize ->
#
# >                         {Columns -> {{Automatic}}, Rows -> {{Automatic}}},
#
# >                        ColumnsEqual -> False, RowsEqual -> False,
#
# >                        GridBoxDividers ->
#
# >                         {Columns ->
#
# >                           {GrayLevel[0.84], GrayLevel[0.84], GrayLevel[0.84],
#
# >                            GrayLevel[0.84]}, Rows -> {{GrayLevel[0.84]}},
#
# >                          RowsIndexed -> {1 -> GrayLevel[0.84], -1 -> GrayLevel[0.84]}}\
#
# >                         , GridBoxSpacings -> {Columns -> {2, 2, 2, 2}, Rows -> {{1}}},
#
# >                        GridBoxAlignment ->
#
# >                         {Columns -> {{Left}}, Rows -> {{Baseline}}},
#
# >                        AllowScriptLevelChange -> False, BaselinePosition -> 1],
#
# >                       TagBoxWrapper[Separator ->  | ]], LineSpacing -> {1, 0, 1.5},
#
# >                      LineIndent -> 0], BaselinePosition -> Center]}},
#
# >                  GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}},
#
# >                  ColumnsEqual -> False, RowsEqual -> False,
#
# >                  GridBoxSpacings ->
#
# >                   {Columns -> {{AbsoluteThickness[-1]}}, Rows -> {{0}}},
#
# >                  AllowScriptLevelChange -> False], TagBoxWrapper[Separator ->  | ]],
#
# >                PolynomialForm[#1, TraditionalOrder -> False] & ], TraditionalForm]],
#
# >             Output, {Background -> None,
#
# >              GraphicsBoxOptions ->
#
# >               {DefaultBaseStyle -> {FontFamily -> Times, Graphics},
#
# >                DefaultAxesStyle ->
#
# >                 Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25],
#
# >                  FontOpacity -> 1, GraphicsAxes],
#
# >                DefaultFrameStyle ->
#
# >                 Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25],
#
# >                  FontOpacity -> 1, GraphicsFrame],
#
# >                DefaultFrameTicksStyle ->
#
# >                 Directive[FontFamily -> Times, FontSize -> 10, GraphicsFrameTicks],
#
# >                DefaultTicksStyle ->
#
# >                 Directive[FontFamily -> Times, FontSize -> 10, GraphicsTicks]},
#
# >              Graphics3DBoxOptions ->
#
# >               {DefaultBaseStyle -> {FontFamily -> Times, Graphics3D}}},
#
# >             NumberPoint -> ., CellSize -> {550, Automatic},
#
# >             AutoStyleOptions -> {HighlightFormattingErrors -> False},
#
# >             RenderingOptions -> {3DRenderingMethod -> BSPTreeOrDepthBuffer}]}],
#
# >          XMLElement[dataformats, {}, {plaintext,minput}]}],
#
# >        XMLElement[expressiontypes, {count -> 1},
#
# >         {   , XMLElement[expressiontype, {name -> Grid}, {}],   }],
#
#
# >        XMLElement[infos, {count -> 1},
#
# >         {XMLElement[info, {text -> log(x) is the natural logarithm},
#
# >           {XMLElement[link, {url ->
#
# >               http://reference.wolfram.com/language/ref/Log.html,
#
# >              text -> Documentation, title -> Mathematica}, {}],
#
# >            XMLElement[link, {url ->
#
# >               http://functions.wolfram.com/ElementaryFunctions/Log,
#
# >              text -> Properties, title -> Wolfram Functions Site}, {}],
#
# >            XMLElement[link, {url ->
#
# >               http://mathworld.wolfram.com/NaturalLogarithm.html, text -> Definition,
#
# >              title -> MathWorld}, {}]}]}]}],
#
# >     Typeset`pod2 =
#
# >      XMLElement[pod, {title -> Plot, scanner -> Plot, id -> Plot, position -> 200,
#
# >        error -> false, numsubpods -> 1},
#
# >       {XMLElement[subpod, {title -> },
#
# >         {XMLElement[minput, {}, {Plot[Log[Cos[x]] (Cos[x] - Sin[x]), {x, 0, Pi/2}]}],
#
# >          XMLElement[cell, {compressed -> True, string -> False},
#
# >           {Cell[BoxData[FormBox[TagBox[FormBox[StyleBox[DynamicModuleBox[
#
# >                   {CalculateUtilities`GraphicsUtilities`Private`max4000$$ = 0.5,
#
# >                    CalculateUtilities`GraphicsUtilities`Private`min3999$$ = -0.5,
#
# >                    CalculateUtilities`GraphicsUtilities`Private`more$$ = False,
#
# >                    Typeset`show$$ = True, Typeset`bookmarkList$$ = {},
#
# >                    Typeset`bookmarkMode$$ = Menu, Typeset`animator$$,
#
# >                    Typeset`animvar$$ = 1, Typeset`name$$ = "untitled",
#
# >                    Typeset`specs$$ =
#
# >                     {{Hold[CalculateUtilities`GraphicsUtilities`Private`more$$],
#
# >                       {False, True}},
#
# >                      {{Hold[CalculateUtilities`GraphicsUtilities`Private`min3999$$],
#
# >                        -0.5, min}, -1, 1},
#
# >                      {{Hold[CalculateUtilities`GraphicsUtilities`Private`max4000$$],
#
# >                        0.5, max}, -1, 1},
#
# >                      {Hold[Overlay[{Dynamic[RawBoxes[FEPrivate`FrontEndResource[
#
# >                             WABitmaps, PodInfoBackground]]],
#
# >                          Pane[Manipulate`Place[1]   Manipulate`Place[2],
#
# >                           ImageMargins -> {{20, 30}, {10, 10}}]}, {1, 2}, 2,
#
# >                         Alignment -> {Left, Top}]], Manipulate`Dump`ThisIsNotAControl}}
#
# >                     , Typeset`size$$ = Automatic, Typeset`update$$ = 0,
#
# >                    Typeset`initDone$$ = False, Typeset`skipInitDone$$ = False,
#
# >                    CalculateUtilities`GraphicsUtilities`Private`more$4383693$$ =
#
# >                     False, CalculateUtilities`GraphicsUtilities`Private`min3999$438369\
#
# >                      8$$ = 0, CalculateUtilities`GraphicsUtilities`Private`max4000$438\
#
# >                      3699$$ = 0},
#
# >                   DynamicBox[Manipulate`ManipulateBoxes[2, TraditionalForm,
#
# >                     Variables :>
#
# >                      {CalculateUtilities`GraphicsUtilities`Private`max4000$$ = 0.5,
#
# >                       CalculateUtilities`GraphicsUtilities`Private`min3999$$ = -0.5,
#
# >                       CalculateUtilities`GraphicsUtilities`Private`more$$ = False},
#
# >                     ControllerVariables :>
#
# >                      {Hold[CalculateUtilities`GraphicsUtilities`Private`more$$,
#
# >                        CalculateUtilities`GraphicsUtilities`Private`more$4383693$$,
#
# >                        False], Hold[CalculateUtilities`GraphicsUtilities`Private`min39\
#
# >                         99$$, CalculateUtilities`GraphicsUtilities`Private`min3999$438\
#
# >                         3698$$, 0],
#
# >                       Hold[CalculateUtilities`GraphicsUtilities`Private`max4000$$,
#
# >                        CalculateUtilities`GraphicsUtilities`Private`max4000$4383699$$,
#
# >                        0]}, OtherVariables :>
#
# >                      {Typeset`show$$, Typeset`bookmarkList$$, Typeset`bookmarkMode$$,
#
# >                       Typeset`animator$$, Typeset`animvar$$, Typeset`name$$,
#
# >                       Typeset`specs$$, Typeset`size$$, Typeset`update$$,
#
# >                       Typeset`initDone$$, Typeset`skipInitDone$$},
#
# >                     Body :>
#
# >                      Quiet[Function[Null,
#
# >                         CalculateUtilities`GraphicsUtilities`Private`post$4383673[
#
# >                          Plot[##1,
#
# >                           AspectRatio ->
#
# >                            If[TrueQ[CalculateUtilities`GraphicsUtilities`Private`aspe\
#
#                                                      1
# >                               ct], Automatic, -----------]]], HoldAll][
#                                                 GoldenRatio
#
# >                        Log[Cos[x]] (Cos[x] - Sin[x]),
#
# >                        {x, If[NumericQ[CalculateUtilities`GraphicsUtilities`Private`mi\
#
# >                            n3999$$],
#
# >                          (Piecewise[{{0.785398 + 0.839626 Tan[1.50408 #1], #1 < 0}},
#
# >                              0.785398 + 0.839626 Tan[1.50408 #1]] & )[
#
# >                           CalculateUtilities`GraphicsUtilities`Private`min3999$$], 0],
#
# >                         If[NumericQ[CalculateUtilities`GraphicsUtilities`Private`min39\
#
# >                             99$$] &&
#
# >                           NumericQ[CalculateUtilities`GraphicsUtilities`Private`max400\
#
# >                             0$$],
#
# >                          (Piecewise[{{0.785398 + 0.839626 Tan[1.50408 #1], #1 < 0}},
#
# >                              0.785398 + 0.839626 Tan[1.50408 #1]] & )[
#
# >                           If[CalculateUtilities`GraphicsUtilities`Private`min3999$$ ==
#
# >                             CalculateUtilities`GraphicsUtilities`Private`max4000$$,
#
# >                            CalculateUtilities`GraphicsUtilities`Private`min3999$$ +
#
#                                Pi
# >                             ----,
#                               2000
#
# >                            CalculateUtilities`GraphicsUtilities`Private`max4000$$]],
#
#                            Pi
# >                          --]}, ImageSize -> {330.},
#                            2
#
# >                        PlotStyle ->
#
# >                         {{Directive[RGBColor[0.368417, 0.506779, 0.709798],
#
# >                            AbsoluteThickness[1.5]]},
#
# >                          {Directive[RGBColor[0.880722, 0.611041, 0.142051],
#
# >                            AbsoluteThickness[1.5]]},
#
# >                          {Directive[RGBColor[0.560181, 0.691569, 0.194885],
#
# >                            AbsoluteThickness[1.5]]},
#
# >                          {Directive[RGBColor[0.922526, 0.385626, 0.209179],
#
# >                            AbsoluteThickness[1.5]]},
#
# >                          {Directive[RGBColor[0.528488, 0.470624, 0.701351],
#
# >                            AbsoluteThickness[1.5]]}}, PerformanceGoal -> Quality]],
#
# >                     Specifications :>
#
# >                      {{CalculateUtilities`GraphicsUtilities`Private`more$$,
#
# >                        {False, True}, ControlType -> None},
#
# >                       {{CalculateUtilities`GraphicsUtilities`Private`min3999$$, -0.5,
#
# >                         min}, -1, 1, ImageSize -> Tiny, ControlPlacement -> 1},
#
# >                       {{CalculateUtilities`GraphicsUtilities`Private`max4000$$, 0.5,
#
# >                         max}, -1, 1, ImageSize -> Tiny, ControlPlacement -> 2},
#
# >                       Overlay[{Dynamic[RawBoxes[FEPrivate`FrontEndResource[WABitmaps,
#
# >                            PodInfoBackground]]],
#
# >                         Pane[Manipulate`Place[1]   Manipulate`Place[2],
#
# >                          ImageMargins -> {{20, 30}, {10, 10}}]}, {1, 2}, 2,
#
# >                        Alignment -> {Left, Top}]},
#
# >                     Options :>
#
# >                      {ControlPlacement -> Bottom, FrameMargins -> {{0, 0}, {0, 10}},
#
# >                       Paneled -> False, AppearanceElements -> {},
#
# >                       LabelStyle -> {DialogStyle, FontColor -> GrayLevel[0.25]}},
#
# >                     DefaultOptions :> {}], SingleEvaluation -> True],
#
# >                   Initialization :>
#
# >                    ({ReleaseHold[Hold[CalculateUtilities`GraphicsUtilities`Private`WAC\
#
# >                             leanTicks[CalculateUtilities`GraphicsUtilities`Private`tic\
#
# >                              ks_] :=
#
# >                           Module[{CalculateUtilities`GraphicsUtilities`Private`res,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`unitformat},
#
# >                            CalculateUtilities`GraphicsUtilities`Private`res =
#
# >                              DeleteCases[Replace[CalculateUtilities`GraphicsUtilities`\
#
# >                               Private`ticks /.
#
# >                               Style | UnitNumberForm | NumberForm -> (#1 & ),
#
# >                               CalculateUtilities`GraphicsUtilities`Private`t:
#
# >                               {__?NumberQ} :>
#
# >                               Thread[{CalculateUtilities`GraphicsUtilities`Private`t,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`t}]],
#
# >                               {_, , ___}][[All,1 ;; 2]] /.
#
# >                               Superscript[CalculateUtilities`GraphicsUtilities`Private\
#
# >                               `b_Integer,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`p_Integer]\
#
# >                               :> Power[CalculateUtilities`GraphicsUtilities`Private`b,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`p] /.
#
# >                               CalculateUtilities`GraphicsUtilities`Private`a__ :>
#
# >                               Times[CalculateUtilities`GraphicsUtilities`Private`a];
#
# >                             If[MatchQ[CalculateUtilities`GraphicsUtilities`Private`r\
#
# >                               es[[All,2]],
#
# >                               CalculateUtilities`GraphicsUtilities`Private`quants:
#
# >                               {__ShortQuantity | __Quantity} /;
#
# >                               Length[Union[UnitObjectPart /@
#
# >                               CalculateUtilities`GraphicsUtilities`Private`quants]] ==
#
# >                               1],
#
# >                              CalculateUtilities`GraphicsUtilities`Private`unitformat =
#
# >                               ToCDFQuantityFunction[CalculateUtilities`GraphicsUtiliti\
#
# >                               es`Private`res[[1,2]]];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`unitform\
#
# >                              at ->
#
# >                               Thread[{CalculateUtilities`GraphicsUtilities`Private`r\
#
# >                               es[[All,1]],
#
# >                               QuantityPart[CalculateUtilities`GraphicsUtilities`Privat\
#
# >                               e`res[[All,2]],
#
# >                               UnitObjectPart[CalculateUtilities`GraphicsUtilities`Priv\
#
# >                               ate`res[[1,2]]]]}],
#
# >                              CalculateUtilities`GraphicsUtilities`Private`res]];
#
# >                          Options[CalculateUtilities`GraphicsUtilities`Private`post$438\
#
# >                             3673] =
#
# >                           {ReturnInteractiveTypes -> False, Nearest -> Automatic};
#
# >                          CalculateUtilities`GraphicsUtilities`Private`post$4383673[
#
# >                            CalculateUtilities`GraphicsUtilities`Private`g_Graphics,
#
# >                            OptionsPattern[]] :=
#
# >                           Check[Module[{CalculateUtilities`GraphicsUtilities`Private`l\
#
# >                               ines, CalculateUtilities`GraphicsUtilities`Private`pts,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`gg,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`type,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`b,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`l,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`t,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`r,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`oldepilog,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`range,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`gridlines,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`oldgridlin\
#
# >                               es,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`neareststy\
#
# >                               le = OptionValue[Nearest]},
#
# >                             CalculateUtilities`GraphicsUtilities`Private`oldepilog =
#
# >                               Replace[Epilog /.
#
# >                               Options[CalculateUtilities`GraphicsUtilities`Private`g],
#
# >                               Epilog -> Sequence[]];
#
# >                              Switch[{Frame, Axes} /.
#
# >                               Options[CalculateUtilities`GraphicsUtilities`Private`g],
#
# >                               {True, _},
#
# >                               CalculateUtilities`GraphicsUtilities`Private`type =
#
# >                               Frame;
#
# >                               {CalculateUtilities`GraphicsUtilities`Private`b,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`l,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`t,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`r} =
#
# >                               CalculateUtilities`GraphicsUtilities`Private`ScaleCoordi\
#
# >                               natesToTicks[Frame,
#
# >                               FrameTicks /.
#
# >                               Options[CalculateUtilities`GraphicsUtilities`Private`g]]\
#
# >                               , {_, True},
#
# >                               CalculateUtilities`GraphicsUtilities`Private`type =
#
# >                               Axes;
#
# >                               {CalculateUtilities`GraphicsUtilities`Private`b,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`l} =
#
# >                               CalculateUtilities`GraphicsUtilities`Private`ScaleCoordi\
#
# >                               natesToTicks[Axes,
#
# >                               Ticks /.
#
# >                               Options[CalculateUtilities`GraphicsUtilities`Private`g]]\
#
# >                               , _,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`type = None]
#
# >                               ; If[CalculateUtilities`GraphicsUtilities`Private`ty\
#
# >                              pe === Frame &&
#
# >                               (!(CalculateUtilities`GraphicsUtilities`Private`t ===
#
# >                               None ||
#
# >                               CalculateUtilities`GraphicsUtilities`Private`b ===
#
# >                               CalculateUtilities`GraphicsUtilities`Private`t) ||
#
# >                               !(CalculateUtilities`GraphicsUtilities`Private`r ===
#
# >                               None ||
#
# >                               CalculateUtilities`GraphicsUtilities`Private`l ===
#
# >                               CalculateUtilities`GraphicsUtilities`Private`r)),
#
# >                               CalculateUtilities`GraphicsUtilities`Private`type = None]
#
# >                               ; If[TrueQ[OptionValue[ReturnInteractiveTypes]],
#
# >                               Which[CalculateUtilities`GraphicsUtilities`Private`ty\
#
# >                              pe === None ||
#
# >                               CalculateUtilities`GraphicsUtilities`Private`b ===
#
# >                              None ||
#
# >                               CalculateUtilities`GraphicsUtilities`Private`l === None,
#
# >                               {},
#
# >                               FreeQ[CalculateUtilities`GraphicsUtilities`Private`g,
#
# >                               Line | Point], {}, True, {Tooltips, Coordinates}],
#
# >                               If[FreeQ[CalculateUtilities`GraphicsUtilities`Private`g,
#
# >                               Line | Point],
#
# >                               Return[CalculateUtilities`GraphicsUtilities`Private`g]];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gg =
#
# >                               Normal[CalculateUtilities`GraphicsUtilities`Private`g];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`pts =
#
# >                               Partition[Flatten[Cases[CalculateUtilities`GraphicsUtili\
#
# >                               ties`Private`gg[[1]],
#
# >                               Point[CalculateUtilities`GraphicsUtilities`Private`a
#
# >                              _] :> CalculateUtilities`GraphicsUtilities`Private`a,
#
# >                               Infinity]], 2];
#
# >                               If[Length[CalculateUtilities`GraphicsUtilities`Private`p\
#
# >                               ts] < 2,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`lines =
#
# >                               Cases[CalculateUtilities`GraphicsUtilities`Private`gg[[
#
# >                               1]], _Line, Infinity];
#
# >                               If[CalculateUtilities`GraphicsUtilities`Private`lin\
#
# >                              es === {},
#
# >                               Return[CalculateUtilities`GraphicsUtilities`Private`g]];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`pts =
#
# >                               Flatten[Cases[CalculateUtilities`GraphicsUtilities`Priva\
#
# >                               te`lines,
#
# >                               Line[CalculateUtilities`GraphicsUtilities`Private`a_] :>
#
# >                               CalculateUtilities`GraphicsUtilities`Private`a, Infinity]
#
# >                               , 1];
#
# >                               If[CalculateUtilities`GraphicsUtilities`Private`nearests\
#
# >                               tyle === Automatic,
#
# >                               If[CalculateUtilities`GraphicsUtilities`Private`orderedL\
#
# >                               ines[CalculateUtilities`GraphicsUtilities`Private`lines]\
#
# >                               , CalculateUtilities`GraphicsUtilities`Private`nearestst\
#
# >                               yle = 1D,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`neareststy\
#
# >                               le = 2D]; ],
#
# >                               If[CalculateUtilities`GraphicsUtilities`Private`nearests\
#
# >                               tyle === Automatic,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`neareststy\
#
# >                               le = 2D]];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`range =
#
# >                               Replace[PlotRange /.
#
# >                               Options[CalculateUtilities`GraphicsUtilities`Private`g],
#
# >                               Except[{{_?NumberQ, _?NumberQ},
#
# >                              {_?NumberQ, _?NumberQ}}] :>
#
# >                               {Through[{Min, Max}[CalculateUtilities`GraphicsUtilities\
#
# >                               `Private`pts[[All,1]]]],
#
# >                               Through[{Min, Max}[CalculateUtilities`GraphicsUtilities`\
#
# >                               Private`pts[[All,2]]]]}];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`b =
#
# >                               CalculateUtilities`GraphicsUtilities`Private`RefineCoord\
#
# >                               inateFunction[CalculateUtilities`GraphicsUtilities`Priva\
#
# >                               te`b,
#
# >                               First[CalculateUtilities`GraphicsUtilities`Private`ran\
#
# >                               ge],
#
# >                               CalculateUtilities`GraphicsUtilities`Private`pts[[All,
#
# >                               1]]];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`l =
#
# >                               CalculateUtilities`GraphicsUtilities`Private`RefineCoord\
#
# >                               inateFunction[CalculateUtilities`GraphicsUtilities`Priva\
#
# >                               te`l,
#
# >                               Last[CalculateUtilities`GraphicsUtilities`Private`ran\
#
# >                              ge],
#
# >                               CalculateUtilities`GraphicsUtilities`Private`pts[[All,
#
# >                               2]]];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`oldgridlin\
#
# >                               es =
#
# >                               GridLines /.
#
# >                               Options[CalculateUtilities`GraphicsUtilities`Private`g];
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gridlines =
#
# >                               With[{CalculateUtilities`GraphicsUtilities`Private`gr\
#
# >                              ay = GrayLevel[0.7]},
#
# >                               Replace[CalculateUtilities`GraphicsUtilities`Private`old\
#
# >                               gridlines,
#
# >                               {CalculateUtilities`GraphicsUtilities`Private`a:
#
# >                               {_List, _List} :>
#
# >                               Dynamic[Join[CalculateUtilities`GraphicsUtilities`Privat\
#
# >                               e`a,
#
# >                               Replace[MousePosition[{Graphics, Graphics}, None],
#
# >                               {None -> {{}, {}},
#
# >                               {CalculateUtilities`GraphicsUtilities`Private`x_,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`y_} :>
#
# >                               {{{CalculateUtilities`GraphicsUtilities`Private`x,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gray}},
#
# >                               {{CalculateUtilities`GraphicsUtilities`Private`y,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gray}}}}],
#
# >                               2]],
#
# >                               {CalculateUtilities`GraphicsUtilities`Private`a_List,
#
# >                               Automatic} :>
#
# >                               With[{CalculateUtilities`GraphicsUtilities`Private`divis\
#
# >                               ions =
#
# >                               {CalculateUtilities`GraphicsUtilities`Private`a,
#
# >                               FindDivisions[Last[CalculateUtilities`GraphicsUtilities`\
#
# >                               Private`range], 7]}},
#
# >                               Dynamic[Join[CalculateUtilities`GraphicsUtilities`Privat\
#
# >                               e`divisions,
#
# >                               Replace[MousePosition[{Graphics, Graphics}, None],
#
# >                               {None -> {{}, {}},
#
# >                               {CalculateUtilities`GraphicsUtilities`Private`x_,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`y_} :>
#
# >                               {{{CalculateUtilities`GraphicsUtilities`Private`x,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gray}},
#
# >                               {{CalculateUtilities`GraphicsUtilities`Private`y,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gray}}}}],
#
# >                               2]]],
#
# >                               _ ->
#
# >                               Dynamic[({{#1,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gray}} & )\
#
# >                               /@ MousePosition[{Graphics, Graphics}, None]]}]];
#
# >                               If[CalculateUtilities`GraphicsUtilities`Private`type ===
#
# >                               None ||
#
# >                               CalculateUtilities`GraphicsUtilities`Private`b ===
#
# >                              None ||
#
# >                               CalculateUtilities`GraphicsUtilities`Private`l === None,
#
# >                               Show[CalculateUtilities`GraphicsUtilities`Private`g,
#
# >                               GridLines ->
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gridlines,
#
# >                               If[MatchQ[CalculateUtilities`GraphicsUtilities`Private`o\
#
# >                               ldgridlines, None | GridLines],
#
# >                               Method -> {GridLinesInFront -> True}, Sequence @@ {}]],
#
# >                               With[{CalculateUtilities`GraphicsUtilities`Private`nf =
#
# >                               If[CalculateUtilities`GraphicsUtilities`Private`nearests\
#
# >                               tyle === 1D,
#
# >                               With[{CalculateUtilities`GraphicsUtilities`Private`n =
#
# >                               Nearest[CalculateUtilities`GraphicsUtilities`Private`p\
#
# >                               ts[[All,1]] ->
#
# >                               CalculateUtilities`GraphicsUtilities`Private`pts]},
#
# >                               CalculateUtilities`GraphicsUtilities`Private`n[
#
# >                              #1[[1]]] & ],
#
# >                               With[{CalculateUtilities`GraphicsUtilities`Private`n =
#
# >                               Nearest[Transpose[Transpose[CalculateUtilities`GraphicsU\
#
# >                               tilities`Private`pts] /
#
# >                               Abs[Apply[Subtract,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`range, {1}]]
#
# >                               ] -> CalculateUtilities`GraphicsUtilities`Private`pts],
#
# >                               CalculateUtilities`GraphicsUtilities`Private`scale =
#
# >                               Abs[Apply[Subtract,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`range, {1}]]
#
# >                               }, CalculateUtilities`GraphicsUtilities`Private`n[
#
# >                               #1 / CalculateUtilities`GraphicsUtilities`Private`scale]\
#
# >                               & ]],
#
# >                               CalculateUtilities`GraphicsUtilities`Private`left =
#
# >                               CalculateUtilities`GraphicsUtilities`Private`l,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`bottom =
#
# >                               CalculateUtilities`GraphicsUtilities`Private`b},
#
# >                               Show[CalculateUtilities`GraphicsUtilities`Private`g,
#
# >                               GridLines ->
#
# >                               CalculateUtilities`GraphicsUtilities`Private`gridlines,
#
# >                               If[MatchQ[CalculateUtilities`GraphicsUtilities`Private`o\
#
# >                               ldgridlines, None | GridLines],
#
# >                               Method -> {GridLinesInFront -> True}, Sequence @@ {}],
#
# >                               Epilog ->
#
# >                               {CalculateUtilities`GraphicsUtilities`Private`oldepilog,
#
# >                               Dynamic[DynamicModule[{CalculateUtilities`GraphicsUtilit\
#
# >                               ies`Private`pt =
#
# >                               CalculateUtilities`GraphicsUtilities`Private`nf[
#
# >                               MousePosition[{Graphics, Graphics}, {0, 0}]],
#
# >                               CalculateUtilities`GraphicsUtilities`Private`scaled =
#
# >                               MousePosition[{GraphicsScaled, Graphics}, None]},
#
# >                               If[CalculateUtilities`GraphicsUtilities`Private`scal\
#
# >                              ed === None, {},
#
# >                               {Text[CalculateUtilities`GraphicsUtilities`Private`bott\
#
# >                               om[CalculateUtilities`GraphicsUtilities`Private`pt[[1,
#
# >                               1]]],
#
# >                               CalculateUtilities`GraphicsUtilities`Private`left[
#
# >                               CalculateUtilities`GraphicsUtilities`Private`pt[[1,2]]],
#
# >                               CalculateUtilities`GraphicsUtilities`Private`pt[[1]],
#
# >                               {1.5
#
# >                               Sign[CalculateUtilities`GraphicsUtilities`Private`scal\
#
# >                               ed[[1]] - 0.5], 0}, Background -> White],
#
# >                               AbsolutePointSize[7],
#
# >                               Point[CalculateUtilities`GraphicsUtilities`Private`pt],
#
# >                               White, AbsolutePointSize[5],
#
# >                               Point[CalculateUtilities`GraphicsUtilities`Private`pt]}]]
#
# >                               ]}]]]]], CalculateUtilities`GraphicsUtilities`Private`g]\
#
# >                           ; CalculateUtilities`GraphicsUtilities`Private`post$4383673[
#
# >                            CalculateUtilities`GraphicsUtilities`Private`g_, ___] :=
#
# >                           CalculateUtilities`GraphicsUtilities`Private`g;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`orderedLines[
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`l__Line}] :=
#
# >                           Module[{CalculateUtilities`GraphicsUtilities`Private`order\
#
# >                              ed, CalculateUtilities`GraphicsUtilities`Private`interva\
#
# >                              ls},
#
# >                            CalculateUtilities`GraphicsUtilities`Private`ordered =
#
# >                              And @@
#
# >                               (OrderedQ[#1[[1,All,1]]] & ) /@
#
# >                               Hold[CalculateUtilities`GraphicsUtilities`Private`l];
#
# >                             If[!TrueQ[CalculateUtilities`GraphicsUtilities`Private`ord\
#
# >                               ered], Return[False]];
#
# >                             CalculateUtilities`GraphicsUtilities`Private`intervals =
#
# >                              {CalculateUtilities`GraphicsUtilities`Private`l}[[All,1,
#
# >                               {1, -1},1]];
#
# >                             Length[Interval @@
#
# >                               CalculateUtilities`GraphicsUtilities`Private`intervals]\
#
# >                               === Length[CalculateUtilities`GraphicsUtilities`Private`\
#
# >                               intervals]];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`ScaleCoordinates\
#
# >                             ToTicks[Frame, Automatic | FrameTicks] =
#
# >                           {Identity, Identity, Identity, Identity};
#
# >                          CalculateUtilities`GraphicsUtilities`Private`ScaleCoordinates\
#
# >                             ToTicks[Frame,
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`b_,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`l_,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`t_,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`r_}] :=
#
# >                           CalculateUtilities`GraphicsUtilities`Private`TicksToFuncti\
#
# >                             on /@
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`b,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`l,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`t,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`r};
#
# >                          CalculateUtilities`GraphicsUtilities`Private`ScaleCoordinates\
#
# >                             ToTicks[Frame,
#
# >                            {{CalculateUtilities`GraphicsUtilities`Private`l_,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`r_},
#
# >                             {CalculateUtilities`GraphicsUtilities`Private`b_,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`t_}}] :=
#
# >                           CalculateUtilities`GraphicsUtilities`Private`TicksToFuncti\
#
# >                             on /@
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`b,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`l,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`t,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`r};
#
# >                          CalculateUtilities`GraphicsUtilities`Private`ScaleCoordinates\
#
# >                             ToTicks[Frame, _] = {None, None, None, None};
#
# >                          CalculateUtilities`GraphicsUtilities`Private`ScaleCoordinates\
#
# >                             ToTicks[Axes, Automatic | Ticks] = {Identity, Identity};
#
# >                          CalculateUtilities`GraphicsUtilities`Private`ScaleCoordinates\
#
# >                             ToTicks[Axes,
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`h_,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`v_}] :=
#
# >                           CalculateUtilities`GraphicsUtilities`Private`TicksToFuncti\
#
# >                             on /@
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`h,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`v};
#
# >                          CalculateUtilities`GraphicsUtilities`Private`ScaleCoordinates\
#
# >                             ToTicks[Axes, _] = {None, None};
#
# >                          CalculateUtilities`GraphicsUtilities`Private`CDFCleanTicks[
#
# >                            CalculateUtilities`GraphicsUtilities`Private`ticks_] :=
#
# >                           DeleteCases[CalculateUtilities`GraphicsUtilities`Private`tic\
#
# >                               ks /. Style | NumberForm -> (#1 & ), {_, , ___}][[All,
#
# >                              1 ;; 2]] /.
#
# >                             Superscript[CalculateUtilities`GraphicsUtilities`Private`b
#
# >                               _Integer,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`p_Integer]\
#
# >                               :> Power[CalculateUtilities`GraphicsUtilities`Private`b,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`p] /.
#
# >                            CalculateUtilities`GraphicsUtilities`Private`a__ :>
#
# >                             Times[CalculateUtilities`GraphicsUtilities`Private`a];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`TicksToFunction[
#
# >                            CalculateUtilities`GraphicsUtilities`Private`ticks$_] :=
#
# >                           CalculateUtilities`GraphicsUtilities`Private`iTicksToFuncti\
#
# >                             on[CalculateUtilities`GraphicsUtilities`Private`WACleanTic\
#
# >                              ks[CalculateUtilities`GraphicsUtilities`Private`ticks$]];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`TicksToFunction[
#
# >                            None] = None;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`TicksToFunction[
#
# >                            False] = None;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`TicksToFunction[
#
# >                            True] = None;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`TicksToFunction[
#
# >                            Automatic] = Identity;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`TicksToFunction[
#
# >                            All] = Identity;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`iTicksToFunction[
#
# >                            CalculateUtilities`GraphicsUtilities`Private`func_ ->
#
# >                             CalculateUtilities`GraphicsUtilities`Private`ticks_] :=
#
# >                           Replace[CalculateUtilities`GraphicsUtilities`Private`iTicksT\
#
# >                              oFunction[CalculateUtilities`GraphicsUtilities`Private`ti\
#
# >                              cks],
#
# >                            CalculateUtilities`GraphicsUtilities`Private`f:
#
# >                              Except[None] :>
#
# >                             CalculateUtilities`GraphicsUtilities`Private`func @*
#
# >                              CalculateUtilities`GraphicsUtilities`Private`f];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`iTicksToFunction[
#
# >                            {}] = None;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`iTicksToFunction[
#
# >                            CalculateUtilities`GraphicsUtilities`Private`ticks:
#
# >                             {{_Integer, _String}..}] :=
#
# >                           Which[Quiet[MatchQ[Apply[SameQ,
#
# >                               Map[DateList[#1][[2 ;; All]] & ,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`ticks, {2}]\
#
# >                               , {1}], {True..}]], DateString,
#
# >                            And @@
#
# >                             StringMatchQ[CalculateUtilities`GraphicsUtilities`Private`\
#
# >                               ticks[[All,2]], NumberString],
#
# >                            CalculateUtilities`GraphicsUtilities`Private`iTicksToFuncti\
#
# >                              on[Transpose[{CalculateUtilities`GraphicsUtilities`Privat\
#
# >                               e`ticks[[All,1]],
#
# >                               ToExpression[CalculateUtilities`GraphicsUtilities`Privat\
#
# >                               e`ticks[[All,2]]]}]], True, None];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`iTicksToFunction[
#
# >                            CalculateUtilities`GraphicsUtilities`Private`ticks:
#
# >                             {{_?NumericQ, _?NumericQ}..}] :=
#
# >                           Which[MatchQ[Apply[Equal,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`ticks, {1}],
#
# >                             {True..}], Identity,
#
# >                            MatchQ[Apply[#1 == Log[#2] & ,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`ticks, {1}],
#
# >                             {True..}], Exp,
#
# >                            TrueQ[Quiet[Equal @@
#
# >                               Divide @@
#
# >                               (Transpose[Rest[CalculateUtilities`GraphicsUtilities`Pri\
#
# >                               vate`ticks]] -
#
# >                               CalculateUtilities`GraphicsUtilities`Private`ticks[[1]])]
#
# >                              ], With[{CalculateUtilities`GraphicsUtilities`Private`slo\
#
# >                               pe =
#
# >                               Divide @@
#
# >                               Subtract @@
#
# >                               CalculateUtilities`GraphicsUtilities`Private`ticks[[
#
# >                               {-1, 1}]]},
#
# >                             SetPrecision[(#1 -
#
# >                               CalculateUtilities`GraphicsUtilities`Private`ticks[[1,1]]
#
# >                               ) / CalculateUtilities`GraphicsUtilities`Private`slope +
#
# >                               CalculateUtilities`GraphicsUtilities`Private`ticks[[1,2]]
#
# >                               , 3] & ], True, None];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`iTicksToFunction[
#
# >                            _] = None;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`RefineCoordinate\
#
# >                             Function[CalculateUtilities`GraphicsUtilities`Private`type
#
# >                             _, ___] :=
#
# >                           CalculateUtilities`GraphicsUtilities`Private`type;
#
# >                          CalculateUtilities`GraphicsUtilities`Private`RefineCoordinate\
#
# >                             Function[Identity,
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`min_,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`max_}, _] :=
#
# >                           With[{CalculateUtilities`GraphicsUtilities`Private`nf =
#
# >                              CalculateUtilities`GraphicsUtilities`Private`numberForm,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`acc =
#
# >                              Floor[Max[Ceiling[FullSimplify[Log[10,
#
# >                               Max[Abs[{CalculateUtilities`GraphicsUtilities`Private`m\
#
# >                               in, CalculateUtilities`GraphicsUtilities`Private`max}]]]\
#
# >                               - Log[10,
#
# >                               (CalculateUtilities`GraphicsUtilities`Private`max -
#
# >                               CalculateUtilities`GraphicsUtilities`Private`min) / 100]]
#
# >                               ], 3] -
#
# >                               RealExponent[Max[Abs[{CalculateUtilities`GraphicsUtiliti\
#
# >                               es`Private`min,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`max}]]]]},
#
# >                            CalculateUtilities`GraphicsUtilities`Private`nf[#1,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`acc] & ];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`RefineCoordinate\
#
# >                             Function[Exp,
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`min_,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`max_}, _] :=
#
# >                           With[{CalculateUtilities`GraphicsUtilities`Private`prec =
#
# >                              Max[Ceiling[FullSimplify[Log[10,
#
# >                               Max[Abs[{CalculateUtilities`GraphicsUtilities`Private`m\
#
# >                               in, CalculateUtilities`GraphicsUtilities`Private`max}]]]\
#
# >                               - Log[10,
#
# >                               (CalculateUtilities`GraphicsUtilities`Private`max -
#
# >                               CalculateUtilities`GraphicsUtilities`Private`min) / 100]]
#
# >                               ], 3]}, Quiet[RawBoxes[ToBoxes[Exp[#1]]]] & ];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`RefineCoordinate\
#
# >                             Function[DateString,
#
# >                            {CalculateUtilities`GraphicsUtilities`Private`min_,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`max_},
#
# >                            CalculateUtilities`GraphicsUtilities`Private`pts_] :=
#
# >                           Module[{CalculateUtilities`GraphicsUtilities`Private`dates,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`spec},
#
# >                            CalculateUtilities`GraphicsUtilities`Private`dates =
#
# >                              DateList /@
#
# >                               CalculateUtilities`GraphicsUtilities`Private`pts;
#
# >                             CalculateUtilities`GraphicsUtilities`Private`spec =
#
# >                              Switch[Length /@
#
# >                               Union /@
#
# >                               Transpose[CalculateUtilities`GraphicsUtilities`Private`d\
#
# >                               ates], {_, 1, 1, __}, {Year}, {_, _, 1, __},
#
# >                               {MonthNameShort,  , Year}, _,
#
# >                               {DayShort,  , MonthNameShort,  , Year}];
#
# >                             If[(CalculateUtilities`GraphicsUtilities`Private`max -
#
# >                               CalculateUtilities`GraphicsUtilities`Private`min) /
#
# >                               31536000 > 25,
#
# >                              CalculateUtilities`GraphicsUtilities`Private`spec =
#
# >                               {Year}];
#
# >                             With[{CalculateUtilities`GraphicsUtilities`Private`s =
#
# >                               CalculateUtilities`GraphicsUtilities`Private`spec},
#
# >                              DateString[#1,
#
# >                               CalculateUtilities`GraphicsUtilities`Private`s] & ]];
#
# >                          CalculateUtilities`GraphicsUtilities`Private`numberForm =
#
# >                           Function[{CalculateUtilities`GraphicsUtilities`Private`a,
#
# >                             CalculateUtilities`GraphicsUtilities`Private`acc},
#
# >                            Quiet[RawBoxes[ToBoxes[CalculateUtilities`GraphicsUtilities\
#
# >                               `Private`a]]]]]],
#
# >                       ReleaseHold[Uncompress[6:eJztVm1v0zAQbikw3t/+ARKfEdAJ7QsSoxtj0oC\
#
# >                          SlO/1kkti4drBdrbBnwef3STN2lWK6QBN6YdTfWke3z333PWeHosg6fd6PXXd\
#
# >                          mA+CxckWnp4YMxKzXBQ83j/LJShFBU+u4bM7xoSg94CRHxA7301j3gs5I9qd3\
#
# >                          +D7hEUFIxq+asqopqCmB5LkGY1U7RlLemJ+MmUiIoz+hGfbw53h650XDgZjGR\
#
# >                          OtQXI1bAuZZ5IoSHoIdMOYd4zwb+74uDx+KhgL4XsBPAL10HgnksQGRnDCMB/\
#
# >                          vW682U/cwMU14TGR86TRZeY7aXqC0pDydwCzHNy4m62VbYCJT5bi5X3KzTkEu\
#
# >                          /Fv4QIQ2JuexSduzJdAvjCtG33lZ/XPuBnh+2xZeitPVxGF+uwx5I5qegFqm8\
#
# >                          3nrOjlGqq610c+5uqz5stEgL54y9f/SEVV6OYxXbcOA2bGp8WrtLcNvt4UXOX\
#
# >                          b9XNwPjPnsHCXgquFQCe6jiAs2j6KZ8sBJtH26KjcOh3G34jtEp08FK5zAxFn\
#
# >                          2i+2PRxV4vSmEWLvpBqTD6xkQQA7GFVtu92hK9SgjkkQGeH5dv2yyiahD8biz\
#
# >                          fe0pj6kZYI6QdcsTmsNkoe5ER9mXPypuJZdzTYa8H3INKci1or+N9ZGGXB5Ph\
#
# >                          GckIV7Q1Ks3h1VSYyK9ZT8oQcKccIqQ9Jf52G/u4WIlkKoDieqSjsWBLc2Zfx\
#
# >                          L9ssBHwFOdNXdsz9Hl3baYTSBOa9UFNEkWp83mmO43mW7c0BzoviT4lsR/oHe\
#
# >                          bQrcp/NVNYWkP7taEbk3o1oRuTejWhP93TbAR47/Sb0ZauJ4=]]};
#
# >                      Typeset`initDone$$ = True), DynamicModuleValues :> {},
#
# >                   Deinitialization :> None, UntrackedVariables :> {Typeset`size$$},
#
# >                   SynchronousInitialization -> True,
#
# >                   UnsavedVariables :> {Typeset`initDone$$},
#
# >                   UndoTrackedVariables :> {Typeset`show$$, Typeset`bookmarkMode$$}],
#
# >                  Manipulate, Deployed -> True, StripOnInput -> False], TraditionalForm]
#
# >                 , Manipulate`InterpretManipulate[1]], TraditionalForm]], Output,
#
# >             {Background -> None, GraphicsBoxOptions ->
#
# >               {DefaultBaseStyle -> {FontFamily -> Times, Graphics},
#
# >                DefaultAxesStyle ->
#
# >                 Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25],
#
# >                  FontOpacity -> 1, GraphicsAxes],
#
# >                DefaultFrameStyle ->
#
# >                 Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25],
#
# >                  FontOpacity -> 1, GraphicsFrame],
#
# >                DefaultFrameTicksStyle ->
#
# >                 Directive[FontFamily -> Times, FontSize -> 10, GraphicsFrameTicks],
#
# >                DefaultTicksStyle ->
#
# >                 Directive[FontFamily -> Times, FontSize -> 10, GraphicsTicks]},
#
# >              Graphics3DBoxOptions ->
#
# >               {DefaultBaseStyle -> {FontFamily -> Times, Graphics3D}}},
#
# >             NumberPoint -> ., CellSize -> {550, Automatic},
#
# >             AutoStyleOptions -> {HighlightFormattingErrors -> False},
#
# >             RenderingOptions -> {3DRenderingMethod -> BSPTreeOrDepthBuffer}]}],
#
# >          XMLElement[dataformats, {}, {minput}]}],
#
# >        XMLElement[expressiontypes, {count -> 1},
#
# >         {   , XMLElement[expressiontype, {name -> Default}, {}],   }]}],
#
#
# >     Typeset`pod3 =
#
# >      XMLElement[pod, {title -> Arc length of curve, scanner -> Plot, id -> ArcLength,
#
# >        position -> 300, error -> false, numsubpods -> 1},
#
# >       {XMLElement[subpod, {title -> },
#
# >         {XMLElement[minput, {}, {NIntegrate[Sqrt[1 + (Cos[x] Log[Cos[x]] + Sin[x] (1 +\
#
# >             Log[Cos[x]] - Tan[x]))^2], {x, 0, Pi/2}]}],
#
# >          XMLElement[cell, {compressed -> False, string -> True},
#
# >           {Cell[BoxData[FormBox[TemplateBox[{RowBox[{TagBox[RowBox[{SubsuperscriptBox[
#
# >                       ∫, 0, FractionBox[π, 2]],
#
# >                      RowBox[{TagBox[TagBox[SqrtBox[RowBox[{1, +,
#
# >                             SuperscriptBox[RowBox[{(,
#
# >                               RowBox[{RowBox[{RowBox[{cos, (, x, )}],  ,
#
# >                               RowBox[{log, (, RowBox[{cos, (, x, )}], )}]}], +,
#
# >                               RowBox[{RowBox[{sin, (, x, )}],  ,
#
# >                               RowBox[{(,
#
# >                               RowBox[{1, +,
#
# >                               RowBox[{log, (, RowBox[{cos, (, x, )}], )}], -,
#
# >                               RowBox[{tan, (, x, )}]}], )}]}]}], )}], 2]}]], Identity]\
#
# >                          , #1 & ], RowBox[{, x}]}]}], HoldForm], ≈,
#
# >                   48.7754571743025948649`1.}], "…"}, RowDefault], TraditionalForm]],
#
# >             Output, {Background -> None,
#
# >              GraphicsBoxOptions ->
#
# >               {DefaultBaseStyle -> {FontFamily -> Times, Graphics},
#
# >                DefaultAxesStyle ->
#
# >                 Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25],
#
# >                  FontOpacity -> 1, GraphicsAxes],
#
# >                DefaultFrameStyle ->
#
# >                 Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25],
#
# >                  FontOpacity -> 1, GraphicsFrame],
#
# >                DefaultFrameTicksStyle ->
#
# >                 Directive[FontFamily -> Times, FontSize -> 10, GraphicsFrameTicks],
#
# >                DefaultTicksStyle ->
#
# >                 Directive[FontFamily -> Times, FontSize -> 10, GraphicsTicks]},
#
# >              Graphics3DBoxOptions ->
#
# >               {DefaultBaseStyle -> {FontFamily -> Times, Graphics3D}}},
#
# >             NumberPoint -> ., CellSize -> {550, Automatic},
#
# >             AutoStyleOptions -> {HighlightFormattingErrors -> False},
#
# >             RenderingOptions -> {3DRenderingMethod -> BSPTreeOrDepthBuffer}]}],
#
# >          XMLElement[dataformats, {},
#
# >           {plaintext,minput,moutput,computabledata,formatteddata}]}],
#
# >        XMLElement[expressiontypes, {count -> 1},
#
# >         {   , XMLElement[expressiontype, {name -> Default}, {}],   }],
#
#
# >        XMLElement[states, {count -> 2},
#
# >         {XMLElement[state, {name -> More digits, input -> ArcLength__More digits},
#
# >           {}], XMLElement[state, {name -> Step-by-step solution,
#
# >            input -> ArcLength__Step-by-step solution, stepbystep -> true,
#
# >            buttonstyle -> StepByStepSolution}, {}]}]}],
#
# >     Typeset`aux1 = {True, False, {False}, True},
#
# >     Typeset`aux2 = {True, False, {False}, True},
#
# >     Typeset`aux3 = {True, False, {False}, True}, Typeset`asyncpods = {},
#
# >     Typeset`nonpods =
#
# >      {XMLElement[assumptions, {count -> 1},
#
# >        {XMLElement[assumption, {type -> Function, word -> log,
#
# >           template ->
#
# >            Assuming "log" is the natural logarithm${separator}Use ${desc} instead,
#
# >           count -> 2, pulldown -> false,
#
# >           default -> {"FunClash", "log"} -> {"Log", "dflt"}},
#
# >          {XMLElement[value, {name -> Log, desc -> the natural logarithm,
#
# >             input -> {"FunClash", "log"} -> {"Log"}}, {}],
#
# >           XMLElement[value, {name -> Log10, desc -> the base 10 logarithm,
#
# >             input -> {"FunClash", "log"} -> {"Log10"}}, {}]}]}]},
#
# >     Typeset`initdone = FrontEnd`SuppressEvaluationHash[False],
#
# >     Typeset`queryinfo =
#
# >      {success -> true, error -> false,
#
# >       {http://www.w3.org/XML/1998/namespace, space} -> preserve, numpods -> 3,
#
# >       datatypes -> Plot, timedout -> Plot, timedoutpods -> , timing -> 2.181,
#
# >       parsetiming -> 0.6890000000000001, parsetimedout -> false,
#
# >       recalculated ->
#
# >        https://www6b3.wolframalpha.com/api/v1/recalc.jsp?id=MSPa53521h8a935cbd2g4e5200\
#
# >         004aciaebdiibid25d1494138648170584556,
#
# >       id -> MSP53531h8a935cbd2g4e52000057g4e5gd8bcd36g3,
#
# >       host -> https://www6b3.wolframalpha.com, server -> 9,
#
# >       related ->
#
# >        https://www6b3.wolframalpha.com/api/v1/relatedQueries.jsp?id=MSPa53541h8a935cbd\
#
# >         2g4e5200006561e6e36gg52a5a1494138648170584556, version -> 2.6,
#
# >       inputstring -> Plot[-sqrt[2] * sin[x - pi/4] * log[cos[x]], {x, 0, Pi/2}]},
#
# >     Typeset`sessioninfo =
#
# >      {TimeZone -> 9., Date -> {2023, 8, 29, 22, 22, 8.549673}, Line -> 3,
#
# >       SessionID -> 30787387740359514101}, Typeset`showpods = {1, 2, 3},
#
# >     Typeset`failedpods = {}, Typeset`chosen = {}, Typeset`open = False,
#
# >     Typeset`newq = Plot[-sqrt[2] * sin[x - pi/4] * log[cos[x]], {x, 0, Pi/2}]},
#
# >    Dynamic[AlphaIntegration`FormatAlphaResults[Dynamic[{1,
#
# >        {Typeset`pod1, Typeset`pod2, Typeset`pod3},
#
# >        {Typeset`aux1, Typeset`aux2, Typeset`aux3}, Typeset`chosen, Typeset`open,
#
# >        Typeset`elements, Typeset`q, Typeset`opts, Typeset`nonpods, Typeset`queryinfo,
#
# >        Typeset`sessioninfo, Typeset`showpods, Typeset`failedpods, Typeset`newq}]],
#
# >     TrackedSymbols :> {Typeset`showpods, Typeset`failedpods}],
#
# >    Initialization :>
#
# >     If[!Typeset`initdone === True &&
#
# >       !Typeset`initdone === FrontEnd`SuppressEvaluationHash[True],
#
# >      Null; WolframAlphaClient`Private`doAsyncUpdates[Hold[{Typeset`pod1, Typeset`pod2,
#
# >          Typeset`pod3}], Typeset`asyncpods, Dynamic[Typeset`failedpods]];
#
# >       Typeset`asyncpods = {}; Typeset`initdone = FrontEnd`SuppressEvaluationHash[True]]
#
# >     , DynamicModuleValues :> {}, SynchronousInitialization -> False],
#
# >   BaseStyle -> {Deployed -> True}, Editable -> False, DeleteWithContents -> True,
#
# >   SelectWithContents -> True]

# %%
WolframAlpha["int^(pi/4)_0 1/cosx dx", 
             {{"Input", 1}, "Content"}, 
             PodStates -> {"Input__Step-by-step solution"}]
# Out:
# RawBoxes[StyleBox[FormBox[RowBox[{TagBox[RowBox[{SubsuperscriptBox[∫, 0,
#
# >           FractionBox[π, 4]], RowBox[{TagBox[FractionBox[1, RowBox[{cos, (, x, )}]],
#
# >             #1 & ], RowBox[{, x}]}]}], HoldForm], ,
#
# >       RowBox[{2,  , RowBox[{SuperscriptBox[tanh, RowBox[{-, 1}]], (,
#
# >           RowBox[{tan, (, FractionBox[π, 8], )}], )}]}], ≈,
#
# >       0.8813735870195430248`4.899555152245148}], TraditionalForm], Output,
#
# >    Background -> None, GraphicsBoxOptions ->
#
# >     {DefaultBaseStyle -> {FontFamily -> Times, Graphics},
#
# >      DefaultAxesStyle ->
#
# >       Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25], FontOpacity -> 1,
#
# >        GraphicsAxes], DefaultFrameStyle ->
#
# >       Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25], FontOpacity -> 1,
#
# >        GraphicsFrame], DefaultFrameTicksStyle ->
#
# >       Directive[FontFamily -> Times, FontSize -> 10, GraphicsFrameTicks],
#
# >      DefaultTicksStyle ->
#
# >       Directive[FontFamily -> Times, FontSize -> 10, GraphicsTicks]},
#
# >    Graphics3DBoxOptions -> {DefaultBaseStyle -> {FontFamily -> Times, Graphics3D}},
#
# >    NumberPoint -> ., CellSize -> {550, Automatic},
#
# >    AutoStyleOptions -> {HighlightFormattingErrors -> False},
#
# >    RenderingOptions -> {3DRenderingMethod -> BSPTreeOrDepthBuffer},
#
# >    FontFamily -> Times, FontSize -> 14, ScriptLevel -> 0, Background -> None]]

# %%
WolframAlpha["int^(pi/4)_0 1/cosx dx", 
             {{"Input", 2}, "Content"}, 
             PodStates -> {"Input__Step-by-step solution"}]
# Out:
# RawBoxes[StyleBox[FormBox[StyleBox[GridBox[{{StyleBox[GridBox[{{StyleBox[
#
# >              StyleBox[TemplateBox[{"Compute the definite integral:"}, RowDefault],
#
# >               GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {RowBox[{SubsuperscriptBox[∫, 0, RowBox[{π, /, 4}]],
#
# >               RowBox[{RowBox[{sec, (, x, )}], RowBox[{, x}]}]}]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}},
#
# >           GridBoxSpacings -> {Columns -> {{None}}, Rows -> {{0.5}}}], Column]},
#
# >        {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{⁠, "⁠",
#
# >                 TemplateBox[{"Multiply ", "numerator ", "and ", "denominator ", "of ",
#
# >                   TemplateBox[{RowBox[{sec, (, x, )}], " "}, RowDefault], "by ",
#
# >                   RowBox[{RowBox[{tan, (, x, )}], +, RowBox[{sec, (, x, )}]}]},
#
# >                  RowDefault], ":"}, RowWithSeparators], GrayLevel[0.3],
#
# >               StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {TemplateBox[{" ", " ",
#
# >               RowBox[{SubsuperscriptBox[∫, 0, RowBox[{π, /, 4}]],
#
# >                 RowBox[{TagBox[FractionBox[RowBox[{RowBox[{SuperscriptBox[sec, 2], (,
#
# >                         x, )}], +,
#
# >                       RowBox[{RowBox[{sec, (, x, )}],  , RowBox[{tan, (, x, )}]}]}],
#
# >                     RowBox[{RowBox[{sec, (, x, )}], +, RowBox[{tan, (, x, )}]}]],
#
# >                    HoldForm], RowBox[{, x}]}]}]}, RowDefault]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"For ", "the ",
#
# >                 "integrand ", TemplateBox[{TagBox[FractionBox[RowBox[{
#
# >                       RowBox[{SuperscriptBox[sec, 2], (, x, )}], +,
#
# >                       RowBox[{RowBox[{sec, (, x, )}],  , RowBox[{tan, (, x, )}]}]}],
#
# >                     RowBox[{RowBox[{sec, (, x, )}], +, RowBox[{tan, (, x, )}]}]],
#
# >                    HoldForm], ",", " "}, RowDefault], "substitute ",
#
# >                 TemplateBox[{RowBox[{u, ,
#
# >                     RowBox[{RowBox[{tan, (, x, )}], +, RowBox[{sec, (, x, )}]}]}], " "}
#
# >                   , RowDefault], "and ",
#
# >                 TemplateBox[{RowBox[{RowBox[{, u}], ,
#
# >                     RowBox[{(, RowBox[{RowBox[{SuperscriptBox[sec, 2], (, x, )}], +,
#
# >                         RowBox[{RowBox[{tan, (, x, )}],  , RowBox[{sec, (, x, )}]}]}],
#
# >                       )}]}], " "}, RowDefault],
#
# >                 TemplateBox[{RowBox[{, x}], ".", "\nThis", " "}, RowDefault],
#
# >                 "gives ", "a ", "new ", "lower ", "bound ",
#
# >                 TemplateBox[{RowBox[{u, ,
#
# >                     RowBox[{RowBox[{tan, (, 0, )}], +, RowBox[{sec, (, 0, )}]}], , 1}]
#
# >                    , " "}, RowDefault], "and ", "upper ", "bound ",
#
# >                 TemplateBox[{RowBox[{u, ,
#
# >                     RowBox[{RowBox[{tan, (, FractionBox[π, 4], )}], +,
#
# >                       RowBox[{sec, (, FractionBox[π, 4], )}]}], ,
#
# >                     RowBox[{1, +, SqrtBox[2]}]}], ":"}, RowDefault]}, RowDefault],
#
# >               GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {TemplateBox[{" ", " ",
#
# >               RowBox[{SubsuperscriptBox[∫, 1, RowBox[{1, +, SqrtBox[2]}]],
#
# >                 RowBox[{FractionBox[1, u], RowBox[{, u}]}]}]}, RowDefault]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"Apply ",
#
# >                 "the ", "fundamental ", "theorem ", "of ", "calculus.\nThe ",
#
# >                 "antiderivative ", "of ",
#
# >                 TemplateBox[{FractionBox[1, u], " "}, RowDefault], "is ",
#
# >                 TemplateBox[{RowBox[{log, (, u, )}], ":"}, RowDefault]}, RowDefault],
#
# >               GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {TemplateBox[{" ", " ",
#
# >               TemplateBox[{RowBox[{log, (, u, )}], 1, RowBox[{1, +, SqrtBox[2]}]}, ,
#
# >                DisplayFunction :>
#
# >                 (SubsuperscriptBox[RowBox[{#1, StyleBox[, SpanMinSize -> 2.]}], #2,
#
# >                    #3] & )]}, RowDefault]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{⁠, "⁠",
#
# >                 TemplateBox[{"Evaluate ", "the ", "antiderivative ", "at ", "the ",
#
# >                   "limits ", "and ", "subtract.\n ",
#
# >                   RowBox[{TemplateBox[{RowBox[{log, (, u, )}], 1,
#
# >                       RowBox[{1, +, SqrtBox[2]}]}, ,
#
# >                      DisplayFunction :>
#
# >                       (SubsuperscriptBox[RowBox[{#1, StyleBox[, SpanMinSize -> 2.]}],
#
# >                          #2, #3] & )], ,
#
# >                     RowBox[{RowBox[{log, (, RowBox[{1, +, SqrtBox[2]}], )}], -,
#
# >                       RowBox[{log, (, 1, )}]}], ,
#
# >                     RowBox[{log, (, RowBox[{1, +, SqrtBox[2]}], )}]}]}, RowDefault],
#
# >                 ":"}, RowWithSeparators], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {TemplateBox[{" ", " ", RowBox[{log, (, RowBox[{1, +, SqrtBox[2]}], )}]},
#
# >              RowDefault]}}, GridBoxAlignment -> {Columns -> {{Left}}},
#
# >           AllowScriptLevelChange -> False, DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}, {StyleBox[GridBox[{{StyleBox[StyleBox[TemplateBox[{"Which ", "is ",
#
# >                 "equal ", "to:"}, RowDefault], GrayLevel[0.3], StripOnInput -> False],
#
# >              {LinebreakAdjustments -> {1, 89, 100, 0, 100},
#
# >               LinebreakAdjustments -> {1, 100, 1, 0, 100}, LineIndent -> 0}]},
#
# >            {FrameBox[StyleBox[GridBox[{{StyleBox[TemplateBox[{"Answer:"}, RowDefault],
#
# >                   FontFamily -> Roboto, FontSize -> 12, StripOnInput -> False], },
#
# >                 {"", TemplateBox[{" ", " ",
#
# >                    RowBox[{2,  , RowBox[{SuperscriptBox[tanh, RowBox[{-, 1}]], (,
#
# >                        RowBox[{tan, (, FractionBox[π, 8], )}], )}]}]}, RowDefault]}},
#
# >                GridBoxAlignment -> {Columns -> {{Left}}, Rows -> {{Baseline}}},
#
# >                AutoDelete -> False, GridBoxItemSize -> {Columns -> {2.5, Automatic}},
#
# >                GridBoxSpacings -> {Columns -> {2, 0, 3}, Rows -> {1.5, 1, 2}},
#
# >                AllowScriptLevelChange -> False], Grid],
#
# >              FrameStyle ->
#
# >               Directive[AbsoluteThickness[1], RGBColor[0.52, 0.76, 0.86]],
#
# >              Background -> RGBColor[0.91, 0.98, 1], RoundingRadius -> 3,
#
# >              FrameMargins -> 12, StripOnInput -> False]}},
#
# >           GridBoxAlignment -> {Columns -> {{Left}}}, AllowScriptLevelChange -> False,
#
# >           DefaultBaseStyle -> Column,
#
# >           GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}}],
#
# >          Column]}}, GridBoxAlignment -> {Columns -> {{Left}}},
#
# >       AllowScriptLevelChange -> False, DefaultBaseStyle -> Column,
#
# >       GridBoxDividers -> {Columns -> {{False}}, Rows -> {False, {True}, False}},
#
# >       GridBoxItemSize -> {Columns -> {{Automatic}}, Rows -> {{Automatic}}},
#
# >       GridBoxSpacings -> {Columns -> {{Automatic}}, Rows -> {{3}}},
#
# >       FrameStyle -> GrayLevel[0.7]], Column], TraditionalForm], Output,
#
# >    Background -> None, GraphicsBoxOptions ->
#
# >     {DefaultBaseStyle -> {FontFamily -> Times, Graphics},
#
# >      DefaultAxesStyle ->
#
# >       Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25], FontOpacity -> 1,
#
# >        GraphicsAxes], DefaultFrameStyle ->
#
# >       Directive[GrayLevel[0, 0.35], FontColor -> GrayLevel[0.25], FontOpacity -> 1,
#
# >        GraphicsFrame], DefaultFrameTicksStyle ->
#
# >       Directive[FontFamily -> Times, FontSize -> 10, GraphicsFrameTicks],
#
# >      DefaultTicksStyle ->
#
# >       Directive[FontFamily -> Times, FontSize -> 10, GraphicsTicks]},
#
# >    Graphics3DBoxOptions -> {DefaultBaseStyle -> {FontFamily -> Times, Graphics3D}},
#
# >    NumberPoint -> ., CellSize -> {550, Automatic},
#
# >    AutoStyleOptions -> {HighlightFormattingErrors -> False},
#
# >    RenderingOptions -> {3DRenderingMethod -> BSPTreeOrDepthBuffer},
#
# >    FontFamily -> Times, FontSize -> 14, ScriptLevel -> 0, Background -> None]]
